# %% [markdown]
# # Percentages and Averages

# %% [markdown]
# This notebook will calculate the percentages and averages of the data.

# %%
import pandas as pd
dataframe = pd.read_csv('./Testing transcribed into CSV.csv')
dataframe
# Out:
#                                File     ID Issues  Length  Verbosity  Success  \
# 0   1 (Technical Report - 37 pages)  1-1-0      3     3.0        NaN      0.0
# 1   1 (Technical Report - 37 pages)  1-1-1      1    10.0        0.0      0.5
# 2   1 (Technical Report - 37 pages)  1-1-2      4     5.0        0.0      1.0
# 3   1 (Technical Report - 37 pages)  1-1-3      3    20.0        NaN      0.0
# 4   1 (Technical Report - 37 pages)  1-1-4      1     5.0        NaN      0.5
# 5   1 (Technical Report - 37 pages)  1-2-0      1     5.0        NaN      0.5
# 6   1 (Technical Report - 37 pages)  1-2-1      2     5.0        NaN      0.5
# 7     2 (Revision Notes - 41 pages)  2-1-0    5,1    10.0        1.0      0.5
# 8     2 (Revision Notes - 41 pages)  2-1-1      2    15.0        1.0      0.5
# 9     2 (Revision Notes - 41 pages)  2-1-2      2     NaN        1.0      0.5
# 10    2 (Revision Notes - 41 pages)  2-1-3      2     5.0        1.0      1.0
# ...

# %% [markdown]
# ## Average Success Rate

# %%
Average_Success_Rate = dataframe.loc[:, 'Success'].mean()
Percentage = Average_Success_Rate * 100
print(f"{Average_Success_Rate:.2%} (2 d.p.)")
# Out:
# 0.4523809523809524
# 45.24% (2 d.p.)
